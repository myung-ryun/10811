# %% [markdown]
# <a href="https://colab.research.google.com/github/myung-ryun/10811/blob/main/20260909.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=6
b=1.5
c=2j
print(a,type(a))
print(a,type(b))
print(a,type(c))
print(a+1,type(a+1))
print(a/b,type(a/b))
print(a/2,type(a/2))
print(a//2,type(a//2))
# Out:
# 6 <class 'int'>
# 6 <class 'float'>
# 6 <class 'complex'>
# 7 <class 'int'>
# 4.0 <class 'float'>
# 3.0 <class 'float'>
# 3 <class 'int'>

# %%
a='Hello'
b=''
c=10
d=0
print(bool(a))
print(bool(b))
print(bool(c))
print(bool(d))
# Out:
# True
# False
# True
# False

# %%
a='100'
b='python'
c='name is "짱구"'
d='''name is "코난"'''
print(a, type(a))
print(b, type(b))
print(c, type(c))
print(d, type(d))
# Out:
# 100 <class 'str'>
# python <class 'str'>
# name is "짱구" <class 'str'>
# name is "코난" <class 'str'>

# %%
a='hello'
b='world'
print(a+b)
print(a*3)
print(a<b)
print('h' in a)
print('wor' not in b)
# Out:
# helloworld
# hellohellohello
# True
# True
# False

# %%
a='Hello Python'
print(a[0])
print(a[6])
print(a[-1])
# Out:
# H
# P
# n

# %%
a='Hello python'
print(a[0:5])
print(a[6:])
print(a[:5])
print(a[6:-4])
print(a[0:9:2])
# Out:
# Hello
# python
# Hello
# py
# Hlopt

# %%
a=input('주민등록번호를 입력하세요:')

print('연:20'+a[0:2]+'년')
print('월:'+a[2:4]+'월')
print('일:'+a[4:6]+'일')
# Out:
# 주민등록번호를 입력하세요: 100515
# 연:2010년
# 월:05월
# 일:15일

# %%
original=input('평문 입력: ')
encryption=original[::-1]
encryption=encryption.replace('e','3').replace('o','0').replace('l','1')
print('암호문: '+encryption)
# Out:
# 평문 입력: o
# 암호문: 0
