# %% [markdown]
# <a href="https://colab.research.google.com/github/myung-ryun/10811/blob/main/20260904.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=input('이름:')
b=input('나이:')
print(a, '님 안녕하세요')
print(20-int(b), '년 후면 20살이시네요')
# Out:
# KeyboardInterrupt

# %%
print(7/3)
print(7//3)
print(7%3)
# Out:
# 2.3333333333333335
# 2
# 1

# %%
sec=int(input('시간을 초 단위로 입력하세요:'))
minutes=sec//60
seconds=sec%60
print(f'{minutes}분 {seconds}초')
# Out:
# 시간을 초 단위로 입력하세요:160
# 2분 40초

# %%
print('###################################')
print(['한양과학기술고등학교 학생증'])

input('학번을 입력하세요:')
input('성명을 입력하세요:')
input('소속을 입력하세요:')

print('위 사람은 본 학교의 학생임을 증명함')
print('###################################')
# Out:
# ###################################
# ['한양과학기술고등학교 학생증']
# 학번을 입력하세요:10811
# 성명을 입력하세요:송명륜
# 소속을 입력하세요:한양과학기술고등학교
# 위 사람은 본 학교의 학생임을 증명함
# ###################################
